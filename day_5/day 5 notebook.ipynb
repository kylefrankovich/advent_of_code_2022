# %% [markdown]
# --- Day 5: Supply Stacks ---
#
# The expedition can depart as soon as the final supplies have been unloaded from the ships. Supplies are stored in stacks of marked crates, but because the needed supplies are buried under many other crates, the crates need to be rearranged.
#
# The ship has a giant cargo crane capable of moving crates between stacks. To ensure none of the crates get crushed or fall over, the crane operator will rearrange them in a series of carefully-planned steps. After the crates are rearranged, the desired crates will be at the top of each stack.
#
# The Elves don't want to interrupt the crane operator during this delicate procedure, but they forgot to ask her which crate will end up where, and they want to be ready to unload them as soon as possible so they can embark.
#
# They do, however, have a drawing of the starting stacks of crates and the rearrangement procedure (your puzzle input). For example:
#
#     [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
#
# move 1 from 2 to 1
# move 3 from 1 to 3
# move 2 from 2 to 1
# move 1 from 1 to 2
# In this example, there are three stacks of crates. Stack 1 contains two crates: crate Z is on the bottom, and crate N is on top. Stack 2 contains three crates; from bottom to top, they are crates M, C, and D. Finally, stack 3 contains a single crate, P.
#
# Then, the rearrangement procedure is given. In each step of the procedure, a quantity of crates is moved from one stack to a different stack. In the first step of the above rearrangement procedure, one crate is moved from stack 2 to stack 1, resulting in this configuration:
#
# [D]
# [N] [C]
# [Z] [M] [P]
#  1   2   3
# In the second step, three crates are moved from stack 1 to stack 3. Crates are moved one at a time, so the first crate to be moved (D) ends up below the second and third crates:
#
#         [Z]
#         [N]
#     [C] [D]
#     [M] [P]
#  1   2   3
# Then, both crates are moved from stack 2 to stack 1. Again, because crates are moved one at a time, crate C ends up below crate M:
#
#         [Z]
#         [N]
# [M]     [D]
# [C]     [P]
#  1   2   3
# Finally, one crate is moved from stack 1 to stack 2:
#
#         [Z]
#         [N]
#         [D]
# [C] [M] [P]
#  1   2   3
# The Elves just need to know which crate will end up on top of each stack; in this example, the top crates are C in stack 1, M in stack 2, and Z in stack 3, so you should combine these together and give the Elves the message CMZ.
#
# After the rearrangement procedure completes, what crate ends up on top of each stack?

# %%
# import our data:

f = open('day_five_input.txt', 'r')
stack_data = f.read().splitlines()
f.close()

# %%
stack_data
# Out:
# ['    [C]             [L]         [T]',
#  '    [V] [R] [M]     [T]         [B]',
#  '    [F] [G] [H] [Q] [Q]         [H]',
#  '    [W] [L] [P] [V] [M] [V]     [F]',
#  '    [P] [C] [W] [S] [Z] [B] [S] [P]',
#  '[G] [R] [M] [B] [F] [J] [S] [Z] [D]',
#  '[J] [L] [P] [F] [C] [H] [F] [J] [C]',
#  '[Z] [Q] [F] [L] [G] [W] [H] [F] [M]',
#  ' 1   2   3   4   5   6   7   8   9 ',
#  '',
#  'move 1 from 5 to 6',
#  'move 5 from 6 to 7',
#  'move 10 from 7 to 3',
#  'move 4 from 8 to 4',
#  'move 2 from 5 to 4',
#  'move 4 from 3 to 6',
#  'move 6 from 2 to 4',
#  'move 8 from 6 to 9',
#  'move 5 from 9 to 2',
#  'move 7 from 2 to 7',
#  'move 2 from 1 to 4',
#  'move 3 from 3 to 8',
#  'move 1 from 5 to 9',
#  'move 1 from 3 to 8',
#  'move 1 from 1 to 2',
#  'move 11 from 4 to 6',
#  'move 2 from 5 to 6',
#  'move 10 from 9 to 1',
#  'move 4 from 8 to 3',
#  'move 7 from 7 to 1',
#  'move 9 from 1 to 2',
#  'move 1 from 6 to 5',
#  'move 1 from 5 to 9',
#  'move 5 from 3 to 8',
# ...

# %%
len(stack_data)
# Out:
# 511

# %%
stack_data[7][4]
# Out:
# '['

# %%
instructions = stack_data[10:]
instructions
# Out:
# ['move 1 from 5 to 6',
#  'move 5 from 6 to 7',
#  'move 10 from 7 to 3',
#  'move 4 from 8 to 4',
#  'move 2 from 5 to 4',
#  'move 4 from 3 to 6',
#  'move 6 from 2 to 4',
#  'move 8 from 6 to 9',
#  'move 5 from 9 to 2',
#  'move 7 from 2 to 7',
#  'move 2 from 1 to 4',
#  'move 3 from 3 to 8',
#  'move 1 from 5 to 9',
#  'move 1 from 3 to 8',
#  'move 1 from 1 to 2',
#  'move 11 from 4 to 6',
#  'move 2 from 5 to 6',
#  'move 10 from 9 to 1',
#  'move 4 from 8 to 3',
#  'move 7 from 7 to 1',
#  'move 9 from 1 to 2',
#  'move 1 from 6 to 5',
#  'move 1 from 5 to 9',
#  'move 5 from 3 to 8',
#  'move 2 from 9 to 1',
#  'move 5 from 3 to 9',
#  'move 3 from 6 to 8',
#  'move 5 from 9 to 6',
#  'move 6 from 6 to 3',
#  'move 3 from 3 to 2',
#  'move 1 from 9 to 8',
#  'move 13 from 2 to 3',
#  'move 3 from 8 to 1',
#  'move 11 from 1 to 4',
#  'move 3 from 4 to 1',
#  'move 2 from 6 to 5',
#  'move 4 from 6 to 8',
#  'move 17 from 3 to 9',
#  'move 1 from 1 to 8',
# ...

# %%
stack1 = []
stack2 = []
stack3 = []

# %%
stack1.append('Z')
stack1.append('N')
stack1
# Out:
# ['Z', 'N']

# %%
stack2.append('M')
stack2.append('C')
stack2.append('D')
stack2
# Out:
# ['M', 'C', 'D']

# %%
stack2.pop()
# Out:
# 'D'

# %%
stack2
# Out:
# ['M', 'C']

# %%
stack3.append('P')
stack3
# Out:
# ['P']

# %%
test_instructions = ['move 1 from 2 to 1',
 'move 3 from 1 to 3',
 'move 2 from 2 to 1',
 'move 1 from 1 to 2']

# %%
test_instructions
# Out:
# ['move 1 from 2 to 1',
#  'move 3 from 1 to 3',
#  'move 2 from 2 to 1',
#  'move 1 from 1 to 2']

# %%
print(stack1)
print(stack2)
print(stack3)
# Out:
# ['Z', 'N']
# ['M', 'C', 'D']
# ['P']

# %%
# stack1 = []
# stack2 = []
# stack3 = []

# stack1.append('Z')
# stack1.append('N')

# stack2.append('M')
# stack2.append('C')
# stack2.append('D')

# stack3.append('P')

# print(stack1)
# print(stack2)
# print(stack3)


# for i in test_instructions:
#     # current instructions:
#     current_instructions = [int(j) for j in i.split() if j.isdigit()]
    
#     num_to_move = current_instructions[0]
#     move_from = current_instructions[1]
#     move_to = current_instructions[2]
    
#     # number of pops to perform:
    
#     for i in range(0,num_to_move):
#         # find out which stack we're pulling form
#         if move_from == 1:
#             item_to_add = stack1.pop()
#         elif move_from == 2:
#             item_to_add = stack2.pop()
#         else:
#             item_to_add = stack3.pop()
#         # find out where we're adding it
#         if move_to == 1:
#             stack1.append(item_to_add)
#         elif move_to == 2:
#             stack2.append(item_to_add)
#         else:
#             stack3.append(item_to_add)
    
# print(stack1)
# print(stack2)
# print(stack3)
    
#     print('move',num_to_move,'from',move_from, "to", move_to)
# Out:
# ['Z', 'N']
# ['M', 'C', 'D']
# ['P']

# %%
# manually create our original stacks because we're lazy:

stack1 = []
stack2 = []
stack3 = []
stack4 = []
stack5 = []
stack6 = []
stack7 = []
stack8 = []
stack9 = []

stack1.append('Z')
stack1.append('J')
stack1.append('G')

stack2.append('Q')
stack2.append('L')
stack2.append('R')
stack2.append('P')
stack2.append('W')
stack2.append('F')
stack2.append('V')
stack2.append('C')


stack3.append('F')
stack3.append('P')
stack3.append('M')
stack3.append('C')
stack3.append('L')
stack3.append('G')
stack3.append('R')

stack4.append('L')
stack4.append('F')
stack4.append('B')
stack4.append('W')
stack4.append('P')
stack4.append('H')
stack4.append('M')

stack5.append('G')
stack5.append('C')
stack5.append('F')
stack5.append('S')
stack5.append('V')
stack5.append('Q')

stack6.append('W')
stack6.append('H')
stack6.append('J')
stack6.append('Z')
stack6.append('M')
stack6.append('Q')
stack6.append('T')
stack6.append('L')

stack7.append('H')
stack7.append('F')
stack7.append('S')
stack7.append('B')
stack7.append('V')

stack8.append('F')
stack8.append('J')
stack8.append('Z')
stack8.append('S')

stack9.append('M')
stack9.append('C')
stack9.append('D')
stack9.append('P')
stack9.append('F')
stack9.append('H')
stack9.append('B')
stack9.append('T')

print(stack1)
print(stack2)
print(stack3)
print(stack4)
print(stack5)
print(stack6)
print(stack7)
print(stack8)
print(stack9)
# Out:
# ['Z', 'J', 'G']
# ['Q', 'L', 'R', 'P', 'W', 'F', 'V', 'C']
# ['F', 'P', 'M', 'C', 'L', 'G', 'R']
# ['L', 'F', 'B', 'W', 'P', 'H', 'M']
# ['G', 'C', 'F', 'S', 'V', 'Q']
# ['W', 'H', 'J', 'Z', 'M', 'Q', 'T', 'L']
# ['H', 'F', 'S', 'B', 'V']
# ['F', 'J', 'Z', 'S']
# ['M', 'C', 'D', 'P', 'F', 'H', 'B', 'T']

# %%
# stack1 = []
# stack2 = []
# stack3 = []

# stack1.append('Z')
# stack1.append('N')

# stack2.append('M')
# stack2.append('C')
# stack2.append('D')

# stack3.append('P')

# print(stack1)
# print(stack2)
# print(stack3)


# ['    [C]             [L]         [T]',
#  '    [V] [R] [M]     [T]         [B]',
#  '    [F] [G] [H] [Q] [Q]         [H]',
#  '    [W] [L] [P] [V] [M] [V]     [F]',
#  '    [P] [C] [W] [S] [Z] [B] [S] [P]',
#  '[G] [R] [M] [B] [F] [J] [S] [Z] [D]',
#  '[J] [L] [P] [F] [C] [H] [F] [J] [C]',
#  '[Z] [Q] [F] [L] [G] [W] [H] [F] [M]',
#  ' 1   2   3   4   5   6   7   8   9 ',


# manually create our original stacks because we're lazy:

stack1 = []
stack2 = []
stack3 = []
stack4 = []
stack5 = []
stack6 = []
stack7 = []
stack8 = []
stack9 = []

stack1.append('Z')
stack1.append('J')
stack1.append('G')

stack2.append('Q')
stack2.append('L')
stack2.append('R')
stack2.append('P')
stack2.append('W')
stack2.append('F')
stack2.append('V')
stack2.append('C')


stack3.append('F')
stack3.append('P')
stack3.append('M')
stack3.append('C')
stack3.append('L')
stack3.append('G')
stack3.append('R')

stack4.append('L')
stack4.append('F')
stack4.append('B')
stack4.append('W')
stack4.append('P')
stack4.append('H')
stack4.append('M')

stack5.append('G')
stack5.append('C')
stack5.append('F')
stack5.append('S')
stack5.append('V')
stack5.append('Q')

stack6.append('W')
stack6.append('H')
stack6.append('J')
stack6.append('Z')
stack6.append('M')
stack6.append('Q')
stack6.append('T')
stack6.append('L')

stack7.append('H')
stack7.append('F')
stack7.append('S')
stack7.append('B')
stack7.append('V')

stack8.append('F')
stack8.append('J')
stack8.append('Z')
stack8.append('S')

stack9.append('M')
stack9.append('C')
stack9.append('D')
stack9.append('P')
stack9.append('F')
stack9.append('H')
stack9.append('B')
stack9.append('T')

print(stack1)
print(stack2)
print(stack3)
print(stack4)
print(stack5)
print(stack6)
print(stack7)
print(stack8)
print(stack9)




def get_stack_results(input_instructions):
    result = ''
    for i in input_instructions:
        # current instructions:
        current_instructions = [int(j) for j in i.split() if j.isdigit()]
        
        num_to_move = current_instructions[0]
        move_from = current_instructions[1]
        move_to = current_instructions[2]
        
#         print("## move", num_to_move, "from", move_from, "to", move_to, "##")

        # number of pops to perform:

        for i in range(0,num_to_move):
            # find out which stack we're pulling from
            if move_from == 1:
                item_to_add = stack1.pop()
#                 print("moving", item_to_add, "from stack1")
            elif move_from == 2:
                item_to_add = stack2.pop()
#                 print("moving", item_to_add, "from stack2")
            elif move_from == 3:
                item_to_add = stack3.pop()
#                 print("moving", item_to_add, "from stack3")
            elif move_from == 4:
                item_to_add = stack4.pop()
#                 print("moving", item_to_add, "from stack4")
            elif move_from == 5:
                item_to_add = stack5.pop()
#                 print("moving", item_to_add, "from stack5")
            elif move_from == 6:
                item_to_add = stack6.pop()
#                 print("moving", item_to_add, "from stack6")
            elif move_from == 7:
                item_to_add = stack7.pop()
#                 print("moving", item_to_add, "from stack7")
            elif move_from == 8:
                item_to_add = stack8.pop()
#                 print("moving", item_to_add, "from stack8")
            else:
                item_to_add = stack9.pop()
#                 print("moving", item_to_add, "from stack9")
            # find out where we're adding it
            if move_to == 1:
                stack1.append(item_to_add)
#                 print("to stack1")
            elif move_to == 2:
                stack2.append(item_to_add)
#                 print("to stack2")
            elif move_to == 3:
                stack3.append(item_to_add)
#                 print("to stack3")
            elif move_to == 4:
                stack4.append(item_to_add)
#                 print("to stack4")
            elif move_to == 5:
                stack5.append(item_to_add)
#                 print("to stack5")
            elif move_to == 6:
                stack6.append(item_to_add)
#                 print("to stack6")
            elif move_to == 7:
                stack7.append(item_to_add)
#                 print("to stack7")
            elif move_to == 8:
                stack8.append(item_to_add)
#                 print("to stack8")
            else:
                stack9.append(item_to_add)
#                 print("to stack9")
#             print()
    
#     print(stack1)
#     print(stack2)
#     print(stack3)
#     print(stack4)
#     print(stack5)
#     print(stack6)
#     print(stack7)
#     print(stack8)
#     print(stack9)
#     print()
    result += stack1[-1]
    result += stack2[-1]
    result += stack3[-1]
    result += stack4[-1]
    result += stack5[-1]
    result += stack6[-1]
    result += stack7[-1]
    result += stack8[-1]
    result += stack9[-1]
    print(result)
# Out:
# ['Z', 'J', 'G']
# ['Q', 'L', 'R', 'P', 'W', 'F', 'V', 'C']
# ['F', 'P', 'M', 'C', 'L', 'G', 'R']
# ['L', 'F', 'B', 'W', 'P', 'H', 'M']
# ['G', 'C', 'F', 'S', 'V', 'Q']
# ['W', 'H', 'J', 'Z', 'M', 'Q', 'T', 'L']
# ['H', 'F', 'S', 'B', 'V']
# ['F', 'J', 'Z', 'S']
# ['M', 'C', 'D', 'P', 'F', 'H', 'B', 'T']

# %%
# result: VFJMQLVST are incorrect (made a simple fuckup)
# result WSFTMRHPP is correct, baby
get_stack_results(instructions)
# Out:
# WSFTMRHPP

# %%
# Out:
# ['M']

# %%
stack3
# Out:
# ['P', 'D', 'N', 'Z']

# %%
result = ''
result
# Out:
# ''

# %%
len(instructions)
# Out:
# 501

# %%
for i in range(0,5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
